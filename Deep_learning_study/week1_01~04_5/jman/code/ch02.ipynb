# %% [markdown]
# # ch02-2. 딥러닝을 위한 도구들을 알아봅니다
#
# ## 1. 파이썬 리스트 복습하기

# %%
my_list = [10, 'hello list', 20]
print(my_list[1])
# Out:
# hello list

# %%
my_list2 = [[10,20,30],[40,50,60]]
print(my_list2[1][1])
# Out:
# 50

# %% [markdown]
# ## 2. 넘파이 준비하기
#
# 1. 코랩에서 넘파이 임포트하고 버전 확인하기

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.18.5

# %% [markdown]
# ## 3. 넘파이로 배열 만들기
# : 넘파이는 파이썬의 리스트처럼 숫자와 문자열을 함께 담을 수 없음
#  딥러닝의 경우 다루게 될 데이터는 모두 숫자(문자 데이터가 있어도 숫자로 바꾸어서 입력)이므로 데이터 종류에 대해서는 걱정하지 않아도 됨
#
#  1. array()함수로 2차원 배열 만들기

# %%
my_arr = np.array([[10,20,30],[40,50,60]])
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %% [markdown]
# 2. type() 함수로 넘파이 배열인지 확인하기

# %%
print(type(my_list),type(my_arr))
# Out:
# <class 'list'> <class 'numpy.ndarray'>

# %% [markdown]
# 3. 넘파이 배열에서 요소 선택하기
# : 리스트에서 요소 선택하는 방법과 동일

# %%
my_arr[0][2]
# Out:
# 30

# %% [markdown]
# 4. 넘파이 내장 함수 사용하기
# : sum()함수를 사용하여 반복문을 사용하지 않고도 배열 요소의 전체 합을 계산할 수 있음

# %%
np.sum(my_arr)
# Out:
# 210

# %% [markdown]
# ## 4. 맷플롯립으로 그래프 그리기
# : matplotlib은 파이썬 과학 생태계의 표준 그래프 패키지이다.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. 선 그래프 그리기
# : plt.plot(x축의 값, y축의 값)

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %% [markdown]
# 2. 산점도 그리기
# : scatter point란 x축, y축 값을 이용하여 점으로 그래프를 그린 것

# %%
plt.scatter([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %% [markdown]
# 3. 넘파이 배열로 산점도 그리기
# : random.rnadn()함수를 사용하여 표준 정규 분포를 따르는 난수를 만들 수 있음

# %%
x = np.random.randn(1000) # 표준 정규 분포를 따르는 난수 1000개를 만듦
y = np.random.randn(1000)
plt.scatter(x,y)
plt.show()
