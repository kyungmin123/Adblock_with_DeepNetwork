# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model
import keras
import tensorflow as tf
from flask import Flask, request
import json
from flask_cors import CORS

import urllib.request
from io import BytesIO

app = Flask(__name__)
CORS(app)

def yes_or_no(url):

#   seed = 5
#   tf.random.set_seed(seed)
#   np.random.seed(seed)

    image_w = 64
    image_h = 64

    pixels = image_h * image_w * 3

    X = []

    print(url)
    
    res = urllib.request.urlopen(url).read()
    img = Image.open(BytesIO(res))

    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)

    X.append(data)

    X = np.array(X)
    X = X.astype(float) / 255

    try:
        #model = load_model('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model')
        model = load_model('/model/ad_non_ad_classify.model')
    
        prediction = model.predict(X)
        
        if prediction >= 0.5:
            return 1
        else :
            return 0
    
    except OSError:
        print('에러')
        pass



@app.route('/getresult', methods=['POST'])
def getresult():
    if request.method == 'POST':
        input = request.get_json() # 이미지 url = input[src] 입니다.
        # 판단하는 부분        
        result = yes_or_no(input["src"])
        # 판단 결과 반환하는 부분
        if(result == 1):
            config = {"isAd": "no"}
        else:
            config = {"isAd" : "yes"}
        result = json.dumps(config, ensure_ascii=False)
        return result

if __name__ == '__main__':
    app.run(host= '0.0.0.0', port='4000')
# Out:
# Using TensorFlow backend.
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:4000/ (Press CTRL+C to quit)
# https://ads.mncmedia.co.kr/mad/DONGA/images/adBlit_rs.jpg
# https://ads.mncmedia.co.kr/mad/DONGA/images/adBlit_rs.jpg
# https://js.ad4989.co.kr/etc/reople/donga_ad.gif
# https://cdn1.ad4989.co.kr/04B_j/0L_gU/1608706453594.jpghttps://cdn8.ad4989.co.kr/03_p_j/0L_d0/1608703999076.gifhttps://cdn1.ad4989.co.kr/04C_e/0M4_o/1608703704140.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:24] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:24] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:24] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:24] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:24] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:24] "POST /getresult HTTP/1.1" 200 -
# 에러에러에러
#
#
# 에러에러
#
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# https://js.ad4989.co.kr/etc/reople/reople_logo.jpg
# https://cdn7.ad4989.co.kr/03_p_g/0LN_j/1608706115751.gif
# https://images.dable.io/ad/thumbnails/legacy-resize/210302115044533/2x/16by10
# https://images.dable.io/ad/thumbnails/91xL5q7wAsRN_2x_1588038974
# https://images.dable.io/ad/thumbnails/legacy-resize/2x/1598948718942
# 에러
# https://images.dable.io/ad/thumbnails/legacy-resize/2x/1573693648778
# 에러
# 에러
# 에러
# 에러
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# https://images.dable.io/ad/thumbnails/legacy-resize/210311051207086/2x/16by10
# https://images.dable.io/ad/thumbnails/legacy-resize/210302115044533/2x/16by10
# https://flx973.lporirxe.com/flp/impimg.php?qid=53632313f523732313f5337393&cid=973&p=PNUT&s=http%3A%2F%2Fdonga.com&x=&nci=&adtg=2479&nai=&si=&h=&w=&bp=&pp=&ci=&ip=&ai=banner&di=&pn=&ua=&lat=&lon=&mm=&os=
# https://img.iacstatic.co.kr/adbayimg/templates/trand_logo.gif
# 에러
# 에러
# https://img.iacstatic.co.kr/adbayimg/templates/more.gif
# https://adimg.digitalcamp.co.kr/files/588/8KJ2R8fI5FSk.jpg
# 에러
# 에러
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:25,759] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 34, in yes_or_no
#     img = img.convert("RGB")
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 893, in convert
#     self.load()
#   File "D:\anaconda3\lib\site-packages\PIL\ImageFile.py", line 259, in load
#     raise OSError(
# OSError: image file is truncated (1 bytes not processed)
# 127.0.0.1 - - [17/Apr/2021 16:59:25] "POST /getresult HTTP/1.1" 500 -
# https://dicp.digitalcamp.co.kr/tc/tc_imp.php?message=7058bd1af3d5e6342a35b47c394e7fdfd79c19d160feab62c6d0578da60ca3a0&date=1618646362&param=NTg4XjIwMjZeUF5TXk9UZzRNamsxTURJemZERTJNVEEwTmpZMU9URjhNVEV5TmpZPV5eXjU1MTY
# https://idm.skplanet.com/pixel?nid=29&uid=OTg4Mjk1MDIzfDE2MTA0NjY1OTF8MTEyNjY=
# https://adimg.digitalcamp.co.kr/files/logo/140x30_b.png
# https://adimg.digitalcamp.co.kr/files/logo/15x15.png
# https://wr-im.catad5959.com/wecydrep.com/120x90/070910565032.jpg
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 에러
# 에러
# https://wr-im.catad5959.com/wecydrep.com/120x90/061815075432.jpg
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# https://wr-im.catad5959.com/wecydrep.com/120x90/102315395942.gif
# https://wr-im.catad5959.com/wecydrep.com/120x90/4322_1.jpg
# https://js.ad4989.co.kr/etc/eternalad/img/ad.gif
# 에러
# 에러에러
#
# https://cdn3.ad4989.co.kr/03RW/0KZI/1614826165316.jpg
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:26,720] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B074D3CC0>
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:26,720] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B063767C0>
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 500 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:26] "POST /getresult HTTP/1.1" 200 -
# https://cdn7.ad4989.co.kr/01IT/0KZO/1608692466714.gif
# https://cdn1.ad4989.co.kr/02K_f/0KZ5/1608693023184.jpg
# https://cdn2.ad4989.co.kr/03U8/0K_e_a/1608693054481.jpg
# 에러
# 에러
# https://static.criteo.net/flash/icon/privacy_small.svg
# [2021-04-17 16:59:27,009] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0742D180>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:27,155] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07577C20>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:27,164] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075779A0>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# https://static.criteo.net/flash/icon/adchoices_en.svg
# https://static.criteo.net/flash/icon/close_button.svg
# https://static.criteo.net/flash/icon/criteo_logo.svg
# https://static.criteo.net/flash/icon/privacy.svg
# [2021-04-17 16:59:27,262] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07445810>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:27,273] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B074D7090>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:27,436] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075774A0>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# https://static.criteo.net/flash/icon/privacy.svg
# https://cat.jp.as.criteo.com/delivery/lg.php?cppv=3&cpp=BvTW0F52Gs9gDt93nnK8m4KTlxPkA_3_B64IASXuqScbigaQxhGO33tWWm9gMFurlmeL09Rcf7p4RB3NMpAHEvWfJFBexw6tbOxySl3_riVIpgu42pnpm6UKOUxOK5QYaVU11HLbmZIip9gPsOOobjxnWddOJBiZwAnKnzcBD7aMX-SQDAaFS46-xnBgz2pw6Bfph9lA_AGpAFSChsS-XLPAeouq1S1WA2x_YZZ0lqYTfu33LlcETm83Deeb6qfUw-RIDHiIhxbZNOxX3pCNHFSMPL43hNijYpicEStBtCBkrF4c9HQA_rKI50ZRXdmXRxRNpQ5ZIJO3W5wAMAG8JwnH61ZLv2yF89mdXgqG35QVJIY0CIChpBx7cfFt38qD7prv2OkQyYz9aSeladU33eEtFr4hzU1tKehPQrQ2_x_uI07eTJWO6dUekrj1DULhA01QLA
# https://image.donga.com/adma/body/210414_bdf_120160.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:27,597] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0757E630>
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 500 -
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 200 -
# https://data.adop.cc/collect.php?data=...%3D%3D
# 에러
# https://adimg.donga.com/madv/img/sponsor/icon_spo_koreanair.gif
# 에러
# 에러
# https://image.donga.com/madv/img/sponsor/samsung_sponsor_8730_2.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 200 -
# 에러
# 에러
# https://adimg.donga.com/madv/img/kdu/kdu_88.jpg
# https://www.google.com/ads/measurement/l?ebcid=ALh7CaSDhAOwNWq4VgOxbNkZkUmhrSs8rYupqz3hDMH_B0LyWODHK4-viHev2h7FKmpzwNm7CFVtMlXPtjGl8TyajfiJQ3ijtQ
# https://www.google.com/ads/measurement/l?ebcid=ALh7CaQgUmnfD10verpCYpxzKmsRtnifLw5P7iGWU9ROTlU13NeWvp2IoET6mOivqItK8hylavJB8LePW_be8YZupnw_6c3W8g
# https://image.donga.com/adma/samsung/210216_samsung_72890.gif
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:27] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 에러
# https://image.donga.com/home2012/images/ad/btn_adclose.png
# [2021-04-17 16:59:28,155] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B074348B0>
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 500 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:28,184] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0750C360>
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 500 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# https://image.donga.com/pc/2020/images/common/logo_donga01.png
# 에러
# 에러
# https://image.donga.com/pc/2020/images/common/icon_donag.png
# 에러
# https://dimg.donga.com/wps/NEWS/IMAGE/2021/04/16/106452507.1.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 에러
# https://dimg.donga.com/wps/NEWS/IMAGE/2021/04/16/106452513.1.jpg
# https://dimg.donga.com/a/258/230/90/2/wps/NEWS/IMAGE/2021/04/16/106438033.2.jpg
# https://dimg.donga.com/a/258/230/90/2/wps/NEWS/IMAGE/2021/04/16/106434608.2.jpg
# https://dimg.donga.com/a/258/230/90/2/wps/NEWS/IMAGE/2021/04/16/106434644.1.jpg
# 에러
# 에러
# 에러
# 에러
# https://dimg.donga.com/a/258/230/90/2/wps/NEWS/IMAGE/2021/04/16/106440898.1.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 에러
# https://dimg.donga.com/a/258/230/90/2/wps/NEWS/IMAGE/2021/04/16/106434621.2.jpg
# 에러
# https://dimg.donga.com/a/258/230/90/2/wps/NEWS/IMAGE/2021/04/16/106441032.3.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:28] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:29,033] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B074399F0>
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 500 -
# https://image.donga.com/donga2013/images/donga_sns_reply/login_txt.gif
# https://www.donga.com/news/It/article/all/20210416/106452516/1?ref=main
# https://dimg.donga.com/a/300/60/90/2/wps/NEWS/FEED/Top_Main_Top_2013/106452516.1.thumb.jpg
# 에러
# 에러
# 에러
# https://yellow.contentsfeed.com/RealMedia/ads/Creatives/default/empty.gif
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# https://dimg.donga.com/a/300/170/90/1/wps/STUDIO/FEED/VODA_STUDIO_DONGA/106387884.1.thumb.jpg
# 에러
# https://yellow.contentsfeed.com/RealMedia/ads/Creatives/default/empty.gif
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/17/106456598.2.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/17/106453151.1.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/17/106454833.3.jpg
# 에러
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/17/106456411.2.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 에러
# 에러
# 에러
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/17/106456592.2.jpg
# 에러
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106440482.3.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/17/106453266.1.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/15/106425995.1.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106434089.2.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106438033.2.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 에러
# 에러
# 에러
# 에러
# 에러
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106438033.2.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:29] "POST /getresult HTTP/1.1" 200 -
# 에러
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106434608.2.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106434644.1.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106440898.1.jpg
# https://dimg.donga.com/a/76/60/95/1/wps/NEWS/IMAGE/2021/04/16/106434621.2.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# https://dimg.donga.com/a/353/239/90/1/wps/NEWS/FEED/Mdonga_Home_Topic_2018/106456015.1.thumb.jpg
# 에러
# 에러
# 에러
# 에러
# 에러
# https://dimg.donga.com/a/353/239/90/1/wps/NEWS/FEED/Mdonga_Home_Topic_2018/106453193.1.thumb.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 에러
# https://dimg.donga.com/a/353/239/90/1/wps/NEWS/FEED/Mdonga_Home_Topic_2018/106453037.1.thumb.jpg
# https://dimg.donga.com/a/353/239/90/1/wps/NEWS/FEED/Mdonga_Home_Topic_2018/106457199.2.thumb.jpg
# https://dimg.donga.com/a/353/239/90/1/wps/NEWS/FEED/Mdonga_Home_Topic_2018/106456408.2.thumb.jpg
# https://dimg.donga.com/a/353/239/90/1/wps/NEWS/FEED/Mdonga_Home_Topic_2018/106456603.1.thumb.jpg
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# https://image.donga.com/home2011/images/footer_icon_rss.gif
# 에러
# 에러
# 에러
# 에러
# 에러
# https://yellow.contentsfeed.com/RealMedia/ads/Creatives/default/empty.gif
# 에러
# 127.0.0.1 - - [17/Apr/2021 16:59:30] "POST /getresult HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:31,031] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07577900>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:31,124] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0759E090>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# https://yellow.contentsfeed.com/RealMedia/ads/Creatives/default/empty.gif
# https://yellow.contentsfeed.com/RealMedia/ads/Creatives/default/empty.gif
# https://yellow.contentsfeed.com/RealMedia/ads/Creatives/default/empty.gif
# 에러
# https://data.adop.cc/collect.php?data=...
# https://cds.taboola.com/?uid=b07f8688-e60a-498d-afd6-b962dd7cce9d-tuct6d60b39&_r=8146713
# 에러
# 에러
# https://idm.skplanet.com/pixel?nid=17&uid=c491b6c754ed11eb99cf08f1ea98200e&url=%2F%2Fcdn.interworksmedia.co.kr%2Fempty.html&channel=web&debug=n
# [2021-04-17 16:59:31,363] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0758E450>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:31,416] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07443C20>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# https://idm.skplanet.com/pixel?nid=17&uid=c491b6c754ed11eb99cf08f1ea98200e&url=%2F%2Fcdn.interworksmedia.co.kr%2Fempty.html&channel=web&debug=n
# https://www.google.com/ads/measurement/l?ebcid=ALh7CaTF3A1ANsNju6Tw6DKWDVgMl-1X9dxbX5KpkheMYWhR2bKuTjTwDxdz0oEWsFpbWNlXl1YoC3390UivEDQKu_9ott353Q
# data:image/svg+xml;charset=UTF-8,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20viewBox%3D%220%200%20400%20400%22%20width%3D%22100%25%22%20height%3D%22100%25%22%20preserveAspectRatio%3D%22none%22%3E%3Ctitle%3EShapes%3C%2Ftitle%3E%3Cg%20id%3D%22Ready%22%3E%3Cpath%20d%3D%22M200%2C0C89.543%2C0%2C0%2C89.543%2C0%2C200S89.543%2C400%2C200%2C400s200-89.54309%2C200-200S310.457%2C0%2C200%2C0ZM172.627%2C300.00012%2C150%2C277.37268l77.3728-77.37292-77.3219-77.322%2C22.5763-22.678%2C100.00049%2C100Z%22%20fill%3D%22%23ffffff%22%20fill-rule%3D%22evenodd%22%20data-color-group%3D%220%22%3E%3C%2Fpath%3E%3C%2Fg%3E%3C%2Fsvg%3E
# https://tpc.googlesyndication.com/sadbundle/$csp%3Der3$/1930694960832771317/media/e70aa274ec1ba84443f05796878f86dc.svg
# https://tpc.googlesyndication.com/sadbundle/$csp%3Der3$/1930694960832771317/media/a5a17851bcc5ac9600a9e11aaff5cbdc.svg
# [2021-04-17 16:59:31,576] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0743E2C0>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:31,610] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07525680>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:31,636] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07518F40>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:31,730] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0759E450>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:31,830] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B063BD9F0>
# 127.0.0.1 - - [17/Apr/2021 16:59:31] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:31,892] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
# ...
# 127.0.0.1 - - [17/Apr/2021 16:59:46] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:46,992] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B07406810>
# 127.0.0.1 - - [17/Apr/2021 16:59:46] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:47,063] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075C1720>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:47,126] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0742D3B0>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
# https://tpc.googlesyndication.com/sadbundle/$csp%3Der3$/1930694960832771317/media/a5a17851bcc5ac9600a9e11aaff5cbdc.svg
# https://tpc.googlesyndication.com/sadbundle/$csp%3Der3$/1930694960832771317/media/98b05ffe0aa3e209767a94b60cc8c005.svg
# data:image/svg+xml;charset=UTF-8,%3Csvg%20version%3D%221.1%22%20id%3D%22Layer_1%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%20x%3D%220px%22%20y%3D%220px%22%20viewBox%3D%220%200%20400%20380%22%20enable-background%3D%22new%200%200%20400%20380%22%20xml%3Aspace%3D%22preserve%22%20width%3D%22100%25%22%20height%3D%22100%25%22%20preserveAspectRatio%3D%22none%22%3E%20%3Cpolygon%20fill%3D%22%23ffc107%22%20points%3D%22200%2C0%20261.804%2C125.088%20400%2C145.147%20300%2C242.515%20323.607%2C380%20200%2C315.088%2076.393%2C380%20100%2C242.515%200%2C145.147%20138.196%2C125.088%20%22%20data-color-group%3D%220%22%3E%3C%2Fpolygon%3E%20%3C%2Fsvg%3E
# data:image/svg+xml;charset=UTF-8,%3Csvg%20version%3D%221.1%22%20id%3D%22Layer_1%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%20x%3D%220px%22%20y%3D%220px%22%20viewBox%3D%220%200%20400%20380%22%20enable-background%3D%22new%200%200%20400%20380%22%20xml%3Aspace%3D%22preserve%22%20width%3D%22100%25%22%20height%3D%22100%25%22%20preserveAspectRatio%3D%22none%22%3E%20%3Cpolygon%20fill%3D%22%23ffc107%22%20points%3D%22200%2C0%20261.804%2C125.088%20400%2C145.147%20300%2C242.515%20323.607%2C380%20200%2C315.088%2076.393%2C380%20100%2C242.515%200%2C145.147%20138.196%2C125.088%20%22%20data-color-group%3D%220%22%3E%3C%2Fpolygon%3E%20%3C%2Fsvg%3E
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 200 -
# [2021-04-17 16:59:47,185] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075D71D0>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:47,310] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075C1450>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
# [2021-04-17 16:59:47,316] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075D7540>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
# 에러
# data:image/svg+xml;charset=UTF-8,%3Csvg%20version%3D%221.1%22%20id%3D%22Layer_1%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%20x%3D%220px%22%20y%3D%220px%22%20viewBox%3D%220%200%20400%20380%22%20enable-background%3D%22new%200%200%20400%20380%22%20xml%3Aspace%3D%22preserve%22%20width%3D%22100%25%22%20height%3D%22100%25%22%20preserveAspectRatio%3D%22none%22%3E%20%3Cpolygon%20fill%3D%22%23ffc107%22%20points%3D%22200%2C0%20261.804%2C125.088%20400%2C145.147%20300%2C242.515%20323.607%2C380%20200%2C315.088%2076.393%2C380%20100%2C242.515%200%2C145.147%20138.196%2C125.088%20%22%20data-color-group%3D%220%22%3E%3C%2Fpolygon%3E%20%3C%2Fsvg%3E
# data:image/svg+xml;charset=UTF-8,%3Csvg%20version%3D%221.1%22%20id%3D%22Layer_1%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%20x%3D%220px%22%20y%3D%220px%22%20viewBox%3D%220%200%20400%20380%22%20enable-background%3D%22new%200%200%20400%20380%22%20xml%3Aspace%3D%22preserve%22%20width%3D%22100%25%22%20height%3D%22100%25%22%20preserveAspectRatio%3D%22none%22%3E%20%3Cpolygon%20fill%3D%22%23ffc107%22%20points%3D%22200%2C0%20261.804%2C125.088%20400%2C145.147%20300%2C242.515%20323.607%2C380%20200%2C315.088%2076.393%2C380%20100%2C242.515%200%2C145.147%20138.196%2C125.088%20%22%20data-color-group%3D%220%22%3E%3C%2Fpolygon%3E%20%3C%2Fsvg%3E
# data:image/svg+xml;charset=UTF-8,%3Csvg%20version%3D%221.1%22%20id%3D%22Layer_1%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20xmlns%3Axlink%3D%22http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink%22%20x%3D%220px%22%20y%3D%220px%22%20viewBox%3D%220%200%20400%20380%22%20enable-background%3D%22new%200%200%20400%20380%22%20xml%3Aspace%3D%22preserve%22%20width%3D%22100%25%22%20height%3D%22100%25%22%20preserveAspectRatio%3D%22none%22%3E%20%3Cpolygon%20fill%3D%22%23ffc107%22%20points%3D%22200%2C0%20261.804%2C125.088%20400%2C145.147%20300%2C242.515%20323.607%2C380%20200%2C315.088%2076.393%2C380%20100%2C242.515%200%2C145.147%20138.196%2C125.088%20%22%20data-color-group%3D%220%22%3E%3C%2Fpolygon%3E%20%3C%2Fsvg%3E
# [2021-04-17 16:59:47,377] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B075C83B0>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
# https://www.google.com/ads/measurement/l?ebcid=ALh7CaRI6j7SuI1J7Gw8FnArD309gw6qtY30WUYw4h2vIvxXtUPpWi7F0z5dS14V0Si4uQ5AAMFWXfT1EwcZWNUQOKHrU743rQ
# [2021-04-17 16:59:47,703] ERROR in app: Exception on /getresult [POST]
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "D:\anaconda3\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "D:\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "D:\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-2f52ce7c20a7>", line 64, in getresult
#     result = yes_or_no(input["src"])
#   File "<ipython-input-1-2f52ce7c20a7>", line 32, in yes_or_no
#     img = Image.open(BytesIO(res))
#   File "D:\anaconda3\lib\site-packages\PIL\Image.py", line 2943, in open
#     raise UnidentifiedImageError(
# PIL.UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000026B0742D3B0>
# 127.0.0.1 - - [17/Apr/2021 16:59:47] "POST /getresult HTTP/1.1" 500 -
