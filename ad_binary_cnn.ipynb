# %%
from PIL import Image

data_aug_gen = ImageDataGenerator(rescale=1. / 255,
                                 rotation_range=30,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1
                                 shear_range=0.5
                                 zoom_range=[0.8, 2.0],
                                 horizontal_flip=True,
                                 vertical_flip=True,
                                 fill_mode='nearest')

img = load_img(fname)
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

i = 0
save_to_dir = fname.split("\\")[4] + "/" + fname.split("\\")[5]
if not save_to_dir == "C:\\Users\\kimkm\\광고":
    for batch in data_aug_gen.flow(x, batch_size = 1, save_to_dir=save_to_dir, save_prefix='plus_'+str(file_name_freq),
                                  save_format='jpg')
    
    i += 1
    if i > 10:
        break

# %%
#본 코드 시작

from PIL import Image
import glob, sys, numpy as np
from sklearn.model_selection import train_test_split
from  keras.utils import np_utils

img_dir = 'C:\\Users\\kimkm\\광고'
categories = ['ad', 'non-ad']
np_classes = len(categories)

image_w = 64
image_h = 64


pixel = image_h * image_w * 3 # RGB 값

X = []
y = []

for idx, ad in enumerate(categories):
    img_dir_detail = img_dir + "\\" + ad
    files = glob.glob(img_dir_detail+"/*.jpg")


    for i, f in enumerate(files):
        try:
            img = Image.open(f)
            img = img.convert("RGB")
            img = img.resize((image_w, image_h))
            data = np.asarray(img)
            #Y는 0 아니면 1이니까 idx값으로 넣는다.
            X.append(data)
            y.append(idx)
            #if i % 300 == 0:
            print(ad, " : ", f)
        except:
            print(ad, str(i)+" 번째에서 에러 ")
X = np.array(X)
Y = np.array(y)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

xy = (X_train, X_test, Y_train, Y_test)
#np.save("C:\\Users\\kimkm\\Desktop\\캡스톤 디자인\\데이터 수집\\광고\\binary_image_data.npy", xy)
np.save("C:\\Users\\kimkm\\광고\\numpy_data\\binary_image_data.npy", xy)
# Out:
# Using TensorFlow backend.
# ad  :  C:\Users\kimkm\광고\ad\14674_685444_4.jpg
# ad  :  C:\Users\kimkm\광고\ad\1569487488596_6.jpg
# ad  :  C:\Users\kimkm\광고\ad\1608703704176.jpg
# ad  :  C:\Users\kimkm\광고\ad\1608703999105.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad1.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad10.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad100.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad101.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad102.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad103.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad104.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad105.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad106.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad107.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad108.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad109.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad11.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad110.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad111.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad112.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad113.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad114.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad115.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad116.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad117.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad118.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad119.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad12.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad120.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad121.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad122.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad123.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad124.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad125.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad126.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad127.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad128.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad129.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad13.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad130.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad131.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad132.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad133.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad134.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad135.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad136.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad137.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad138.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad139.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad14.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad140.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad141.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad142.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad143.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad144.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad145.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad146.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad147.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad148.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad149.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad15.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad150.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad151.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad152.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad153.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad154.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad155.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad156.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad157.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad158.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad159.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad16.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad160.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad161.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad162.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad163.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad164.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad165.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad166.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad167.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad168.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad169.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad17.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad170.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad171.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad172.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad173.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad174.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad175.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad176.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad177.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad178.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad179.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad18.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad180.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad181.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad182.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad183.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad184.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad185.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad186.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad187.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad188.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad189.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad19.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad190.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad191.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad192.jpg
# ad  :  C:\Users\kimkm\광고\ad\
jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad58.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad59.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad6.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad60.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad61.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad62.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad63.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad64.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad65.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad66.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad67.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad68.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad69.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad7.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad70.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad71.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad72.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad73.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad74.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad75.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad76.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad77.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad78.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad79.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad8.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad80.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad81.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad82.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad83.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad84.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad85.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad86.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad87.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad88.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad89.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad9.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad90.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad91.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad92.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad93.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad94.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad95.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad96.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad97.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad98.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\ad99.jpg
# D:\anaconda3\lib\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

#X_train, X_test, y_train, y_test = np.load("C:\\Users\\kimkm\\Desktop\\캡스톤 디자인\\데이터 수집\\광고\\binary_image_data.npy", allow_pickle=True)
X_train, X_test, y_train, y_test = np.load("C:\\Users\\kimkm\\광고\\numpy_data\\binary_image_data.npy", allow_pickle=True)

print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (416, 64, 64, 3)
# 416
# [219 197]
# [58 47]

# %%
import os

image_w = 64
image_h = 64
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255


with K.tf_ops.device('/device:GPU:0'):
    model = Sequential()
    
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu")) 
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    model_dir = 'C:\\Users\\kimkm\\광고\\model'
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    model_path = model_dir + "\\ad_non_ad_classify.model"
    
    checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    #early_stopping = EarlyStopping(monitor='val_loss', patience=7)
    #model.save('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model.h5')

# %%
# VGG 16 모델

# import os

# image_w = 64
# image_h = 64
# X_train = X_train.astype('float32') / 255
# X_test = X_test.astype('float32') / 255


# with K.tf_ops.device('/device:GPU:0'):
#     model = Sequential()
    
#     model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
#     model.add(BatchNormalization())

#     model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2,2)))
#     model.add(Dropout(0.25))
    
#     model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2,2)))
#     model.add(Dropout(0.25))
    
#     model.add(Conv2D(128, (3,3), padding="same", activation="relu"))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2,2)))
#     model.add(Dropout(0.25))
    
#     model.add(Conv2D(128, (3,3), padding="same", activation="relu"))
#     model.add(BatchNormalization())
#     model.add(MaxPooling2D(pool_size=(2,2)))
#     model.add(Dropout(0.25))
    
#     model.add(Flatten())
#     model.add(Dense(256, activation="relu"))
#     model.add(Dropout(0.5))
#     model.add(Dense(1, activation="sigmoid"))
    
#     #adam = tf.keras.optimizers.Adam(lr = 0.001)
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
#     model_dir = 'C:\\Users\\kimkm\\광고\\model'
#     if not os.path.exists(model_dir):
#         os.mkdir(model_dir)
#     model_path = model_dir + "\\ad_non_ad_classify.model"
    
#     #checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
#     #early_stopping = EarlyStopping(monitor='val_loss', patience=7)  # 깊은 학습에는 early stopping이 필요 없음
    
#     model.save('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 328,225
# Trainable params: 328,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
#history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.2, callbacks=[checkpoint, early_stopping])
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.2, callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6965 - accuracy: 0.5312
# Epoch 00001: val_loss improved from inf to 0.68825, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# WARNING:tensorflow:From D:\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 3s 518ms/step - loss: 0.6949 - accuracy: 0.5331 - val_loss: 0.6883 - val_accuracy: 0.6429
# Epoch 2/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6824 - accuracy: 0.5656
# Epoch 00002: val_loss improved from 0.68825 to 0.67143, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 2s 413ms/step - loss: 0.6825 - accuracy: 0.5693 - val_loss: 0.6714 - val_accuracy: 0.5595
# Epoch 3/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6963 - accuracy: 0.5250
# Epoch 00003: val_loss did not improve from 0.67143
# 6/6 [==============================] - 1s 97ms/step - loss: 0.6962 - accuracy: 0.5211 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 4/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6859 - accuracy: 0.5281
# Epoch 00004: val_loss did not improve from 0.67143
# 6/6 [==============================] - 1s 102ms/step - loss: 0.6861 - accuracy: 0.5301 - val_loss: 0.6867 - val_accuracy: 0.5238
# Epoch 5/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6720 - accuracy: 0.5500
# Epoch 00005: val_loss improved from 0.67143 to 0.65549, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 3s 434ms/step - loss: 0.6762 - accuracy: 0.5361 - val_loss: 0.6555 - val_accuracy: 0.5595
# Epoch 6/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6545 - accuracy: 0.5781
# Epoch 00006: val_loss did not improve from 0.65549
# 6/6 [==============================] - 1s 98ms/step - loss: 0.6548 - accuracy: 0.5813 - val_loss: 0.6631 - val_accuracy: 0.6190
# Epoch 7/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6455 - accuracy: 0.6719
# Epoch 00007: val_loss improved from 0.65549 to 0.61955, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 2s 393ms/step - loss: 0.6427 - accuracy: 0.6687 - val_loss: 0.6195 - val_accuracy: 0.6190
# Epoch 8/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6290 - accuracy: 0.6156
# Epoch 00008: val_loss did not improve from 0.61955
# 6/6 [==============================] - 1s 103ms/step - loss: 0.6284 - accuracy: 0.6145 - val_loss: 0.6488 - val_accuracy: 0.5952
# Epoch 9/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.5918 - accuracy: 0.6344
# Epoch 00009: val_loss did not improve from 0.61955
# 6/6 [==============================] - 1s 101ms/step - loss: 0.5908 - accuracy: 0.6325 - val_loss: 0.6487 - val_accuracy: 0.6190
# Epoch 10/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.5856 - accuracy: 0.7000
# Epoch 00010: val_loss did not improve from 0.61955
# 6/6 [==============================] - 1s 101ms/step - loss: 0.5806 - accuracy: 0.7048 - val_loss: 0.6428 - val_accuracy: 0.6667
# Epoch 11/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.5453 - accuracy: 0.7063
# Epoch 00011: val_loss did not improve from 0.61955
# 6/6 [==============================] - 1s 98ms/step - loss: 0.5397 - accuracy: 0.7139 - val_loss: 0.6636 - val_accuracy: 0.6786
# Epoch 12/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.5400 - accuracy: 0.7094
# Epoch 00012: val_loss did not improve from 0.61955
# 6/6 [==============================] - 1s 102ms/step - loss: 0.5421 - accuracy: 0.7078 - val_loss: 0.6216 - val_accuracy: 0.7024
# Epoch 13/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.4871 - accuracy: 0.7875
# Epoch 00013: val_loss improved from 0.61955 to 0.59323, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 3s 420ms/step - loss: 0.4829 - accuracy: 0.7922 - val_loss: 0.5932 - val_accuracy: 0.7262
# Epoch 14/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.4737 - accuracy: 0.7812
# Epoch 00014: val_loss improved from 0.59323 to 0.56018, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 3s 424ms/step - loss: 0.4745 - accuracy: 0.7831 - val_loss: 0.5602 - val_accuracy: 0.7857
# Epoch 15/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3976 - accuracy: 0.8375
# Epoch 00015: val_loss improved from 0.56018 to 0.55825, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 3s 419ms/step - loss: 0.4187 - accuracy: 0.8343 - val_loss: 0.5582 - val_accuracy: 0.7857
# Epoch 16/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.4289 - accuracy: 0.8125
# Epoch 00016: val_loss did not improve from 0.55825
# 6/6 [==============================] - 1s 97ms/step - loss: 0.4296 - accuracy: 0.8102 - val_loss: 0.6566 - val_accuracy: 0.7143
# Epoch 17/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.4447 - accuracy: 0.7937
# Epoch 00017: val_loss did not improve from 0.55825
# 6/6 [==============================] - 1s 97ms/step - loss: 0.4368 - accuracy: 0.8012 - val_loss: 0.5605 - val_accuracy: 0.7381
# Epoch 18/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3636 - accuracy: 0.8313
# Epoch 00018: val_loss improved from 0.55825 to 0.52076, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 2s 400ms/step - loss: 0.3605 - accuracy: 0.8343 - val_loss: 0.5208 - val_accuracy: 0.7619
# Epoch 19/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3478 - accuracy: 0.8250
# Epoch 00019: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 99ms/step - loss: 0.3496 - accuracy: 0.8223 - val_loss: 0.6313 - val_accuracy: 0.6905
# Epoch 20/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3935 - accuracy: 0.8313
# Epoch 00020: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3866 - accuracy: 0.8343 - val_loss: 0.6029 - val_accuracy: 0.6786
# Epoch 21/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3643 - accuracy: 0.8313
# Epoch 00021: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3604 - accuracy: 0.8343 - val_loss: 0.5946 - val_accuracy: 0.7024
# Epoch 22/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3574 - accuracy: 0.8594
# Epoch 00022: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 97ms/step - loss: 0.3555 - accuracy: 0.8614 - val_loss: 0.5504 - val_accuracy: 0.7738
# Epoch 23/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3061 - accuracy: 0.8813
# Epoch 00023: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3087 - accuracy: 0.8765 - val_loss: 0.5469 - val_accuracy: 0.7381
# Epoch 24/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2791 - accuracy: 0.8813
# Epoch 00024: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2770 - accuracy: 0.8795 - val_loss: 0.6013 - val_accuracy: 0.7500
# Epoch 25/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2640 - accuracy: 0.8906
# Epoch 00025: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2586 - accuracy: 0.8946 - val_loss: 0.5493 - val_accuracy: 0.7738
# Epoch 26/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2409 - accuracy: 0.8875
# Epoch 00026: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 99ms/step - loss: 0.2487 - accuracy: 0.8825 - val_loss: 0.6854 - val_accuracy: 0.7024
# Epoch 27/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3096 - accuracy: 0.8469
# Epoch 00027: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 101ms/step - loss: 0.3073 - accuracy: 0.8494 - val_loss: 0.6891 - val_accuracy: 0.6905
# Epoch 28/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3504 - accuracy: 0.8344
# Epoch 00028: val_loss did not improve from 0.52076
# 6/6 [==============================] - 1s 97ms/step - loss: 0.3853 - accuracy: 0.8253 - val_loss: 0.5765 - val_accuracy: 0.7857
# Epoch 29/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3701 - accuracy: 0.8219
# Epoch 00029: val_loss improved from 0.52076 to 0.50179, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 3s 422ms/step - loss: 0.3664 - accuracy: 0.8283 - val_loss: 0.5018 - val_accuracy: 0.7143
# Epoch 30/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3382 - accuracy: 0.8438
# Epoch 00030: val_loss improved from 0.50179 to 0.49738, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 6/6 [==============================] - 2s 411ms/step - loss: 0.3337 - accuracy: 0.8464 - val_loss: 0.4974 - val_accuracy: 0.7738
# Epoch 31/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2723 - accuracy: 0.8938
# Epoch 00031: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2667 - accuracy: 0.8976 - val_loss: 0.5930 - val_accuracy: 0.7143
# Epoch 32/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2530 - accuracy: 0.8875
# Epoch 00032: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2521 - accuracy: 0.8855 - val_loss: 0.6050 - val_accuracy: 0.7976
# Epoch 33/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2234 - accuracy: 0.9125
# Epoch 00033: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2283 - accuracy: 0.9096 - val_loss: 0.5829 - val_accuracy: 0.7619
# Epoch 34/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2261 - accuracy: 0.9156
# Epoch 00034: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2272 - accuracy: 0.9157 - val_loss: 0.5035 - val_accuracy: 0.7857
# Epoch 35/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1965 - accuracy: 0.9250
# Epoch 00035: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1942 - accuracy: 0.9277 - val_loss: 0.5324 - val_accuracy: 0.7857
# Epoch 36/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1546 - accuracy: 0.9219
# Epoch 00036: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 96ms/step - loss: 0.1562 - accuracy: 0.9217 - val_loss: 0.5936 - val_accuracy: 0.7738
# Epoch 37/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1634 - accuracy: 0.9438
# Epoch 00037: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1707 - accuracy: 0.9398 - val_loss: 0.6530 - val_accuracy: 0.7262
# Epoch 38/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2148 - accuracy: 0.9125
# Epoch 00038: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2170 - accuracy: 0.9096 - val_loss: 0.7195 - val_accuracy: 0.7738
# Epoch 39/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2198 - accuracy: 0.8875
# Epoch 00039: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2200 - accuracy: 0.8916 - val_loss: 0.5385 - val_accuracy: 0.7619
# Epoch 40/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2163 - accuracy: 0.9031
# Epoch 00040: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2103 - accuracy: 0.9066 - val_loss: 0.6377 - val_accuracy: 0.7619
# Epoch 41/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.
val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0388 - accuracy: 0.9849 - val_loss: 0.7556 - val_accuracy: 0.7738
# Epoch 75/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0241 - accuracy: 0.9937
# Epoch 00075: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0239 - accuracy: 0.9940 - val_loss: 0.8086 - val_accuracy: 0.7619
# Epoch 76/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0221 - accuracy: 0.9937
# Epoch 00076: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0217 - accuracy: 0.9940 - val_loss: 0.9166 - val_accuracy: 0.7619
# Epoch 77/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0180 - accuracy: 0.9969
# Epoch 00077: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0178 - accuracy: 0.9970 - val_loss: 0.9068 - val_accuracy: 0.7381
# Epoch 78/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0239 - accuracy: 0.9969
# Epoch 00078: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0238 - accuracy: 0.9970 - val_loss: 0.9498 - val_accuracy: 0.7381
# Epoch 79/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0126 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.0358 - val_accuracy: 0.7619
# Epoch 80/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0130 - accuracy: 1.0000
# Epoch 00080: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.8543 - val_accuracy: 0.7619
# Epoch 81/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0112 - accuracy: 0.9969
# Epoch 00081: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.9275 - val_accuracy: 0.7500
# Epoch 82/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0147 - accuracy: 0.9937
# Epoch 00082: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 1.0172 - val_accuracy: 0.7381
# Epoch 83/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9963 - val_accuracy: 0.7500
# Epoch 84/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0103 - accuracy: 0.9969
# Epoch 00084: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.9907 - val_accuracy: 0.7381
# Epoch 85/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.0428 - val_accuracy: 0.7619
# Epoch 86/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.9257 - val_accuracy: 0.7738
# Epoch 87/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00087: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.9355 - val_accuracy: 0.7738
# Epoch 88/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0115 - accuracy: 0.9969
# Epoch 00088: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 1.0850 - val_accuracy: 0.7619
# Epoch 89/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0172 - accuracy: 0.9937
# Epoch 00089: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 107ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.8863 - val_accuracy: 0.7738
# Epoch 90/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00090: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.9599 - val_accuracy: 0.7619
# Epoch 91/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00091: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 106ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0903 - val_accuracy: 0.7619
# Epoch 92/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00092: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 108ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9601 - val_accuracy: 0.7857
# Epoch 93/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00093: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.0963 - val_accuracy: 0.7738
# Epoch 94/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00094: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.0817 - val_accuracy: 0.7738
# Epoch 95/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0473 - val_accuracy: 0.7976
# Epoch 96/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0086 - accuracy: 0.9969
# Epoch 00096: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 1.4026 - val_accuracy: 0.7619
# Epoch 97/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0232 - accuracy: 0.9906
# Epoch 00097: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0229 - accuracy: 0.9910 - val_loss: 1.3297 - val_accuracy: 0.7381
# Epoch 98/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0472 - accuracy: 0.9844
# Epoch 00098: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0468 - accuracy: 0.9849 - val_loss: 1.5461 - val_accuracy: 0.7381
# Epoch 99/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0903 - accuracy: 0.9719
# Epoch 00099: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0930 - accuracy: 0.9699 - val_loss: 1.4287 - val_accuracy: 0.7500
# Epoch 100/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.4688 - accuracy: 0.8656
# Epoch 00100: val_loss did not improve from 0.49738
# 6/6 [==============================] - 1s 103ms/step - loss: 0.4640 - accuracy: 0.8645 - val_loss: 0.9110 - val_accuracy: 0.6667

# %%
print("정확도 : %.2f " %(model.evaluate(X_test, y_test, batch_size = 64)[1]))
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4547 - accuracy: 0.7810
# 정확도 : 0.78

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['acc', 'val_acc'], loc='upper left')
plt.show()

# %%
from PIL import Image
#import Image
import os, glob, numpy as np
from tensorflow.keras.models import load_model

import tensorflow as tf

seed = 5
tf.random.set_seed(seed)
np.random.seed(seed)

caltech_dir = 'C:\\Users\\kimkm\\광고\\test'


image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*.jpg")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)

    filenames.append(f)
    X.append(data)
    
X = np.array(X)
X = X.astype(float) / 255

model = load_model('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model')
#model = load_model('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model.h5')


prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)}) # 소수점 3자리까지
cnt = 0
for i in prediction:
    if i >= 0.5: print("해당 " + filenames[cnt].split("\\")[4] + filenames[cnt].split("\\")[5] + "  이미지는 광고 로 추정됩니다.")
    else : print("해당 " + filenames[cnt].split("\\")[4] + filenames[cnt].split("\\")[5] + "  이미지는 비광고 로 추정됩니다.")
    cnt += 1
# Out:
# 해당 test1.jpg  이미지는 광고 로 추정됩니다.
# 해당 test2.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test3.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test4.jpg  이미지는 광고 로 추정됩니다.
# 해당 test5.jpg  이미지는 광고 로 추정됩니다.
# 해당 test6.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test7.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test8.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test9.jpg  이미지는 비광고 로 추정됩니다.
