# %%
#이름 정렬 코드

import os

file_path = 'C:\\Users\\kimkm\\광고\\ad'
file_names = os.listdir(file_path)
file_names
# Out:
# ['ad1.jpg',
#  'ad10.jpg',
#  'ad100.jpg',
#  'ad101.jpg',
#  'ad102.jpg',
#  'ad103.jpg',
#  'ad104.jpg',
#  'ad105.jpg',
#  'ad106.jpg',
#  'ad107.jpg',
#  'ad108.jpg',
#  'ad109.jpg',
#  'ad11.jpg',
#  'ad110.jpg',
#  'ad111.jpg',
#  'ad112.jpg',
#  'ad113.jpg',
#  'ad114.jpg',
#  'ad115.jpg',
#  'ad116.jpg',
#  'ad117.jpg',
#  'ad118.jpg',
#  'ad119.jpg',
#  'ad12.jpg',
#  'ad120.jpg',
#  'ad121.jpg',
#  'ad122.jpg',
#  'ad123.jpg',
#  'ad124.jpg',
#  'ad125.jpg',
#  'ad126.jpg',
#  'ad127.jpg',
#  'ad128.jpg',
#  'ad129.jpg',
#  'ad13.jpg',
#  'ad130.jpg',
#  'ad131.jpg',
#  'ad132.jpg',
#  'ad133.jpg',
#  'ad134.jpg',
#  'ad135.jpg',
#  'ad14.jpg',
#  'ad15.jpg',
#  'ad16.jpg',
#  'ad17.jpg',
#  'ad18.jpg',
#  'ad19.jpg',
#  'ad2.jpg',
#  'ad20.jpg',
#  'ad21.jpg',
#  'ad22.jpg',
#  'ad23.jpg',
#  'ad24.jpg',
#  'ad25.jpg',
#  'ad26.jpg',
#  'ad27.jpg',
#  'ad28.jpg',
#  'ad29.jpg',
#  'ad3.jpg',
#  'ad30.jpg',
#  'ad31.jpg',
#  'ad32.jpg',
#  'ad33.jpg',
#  'ad34.jpg',
#  'ad35.jpg',
#  'ad36.jpg',
#  'ad37.jpg',
#  'ad38.jpg',
#  'ad39.jpg',
#  'ad4.jpg',
#  'ad40.jpg',
#  'ad41.jpg',
#  'ad42.jpg',
#  'ad43.jpg',
#  'ad44.jpg',
#  'ad45.jpg',
#  'ad46.jpg',
#  'ad47.jpg',
#  'ad48.jpg',
#  'ad49.jpg',
#  'ad5.jpg',
#  'ad50.jpg',
#  'ad51.jpg',
#  'ad52.jpg',
#  'ad53.jpg',
#  'ad54.jpg',
#  'ad55.jpg',
#  'ad56.jpg',
#  'ad57.jpg',
#  'ad58.jpg',
#  'ad59.jpg',
#  'ad6.jpg',
#  'ad60.jpg',
#  'ad61.jpg',
#  'ad62.jpg',
#  'ad63.jpg',
#  'ad64.jpg',
#  'ad65.jpg',
#  'ad66.jpg',
#  'ad67.jpg',
#  'ad68.jpg',
#  'ad69.jpg',
#  'ad7.jpg',
#  'ad70.jpg',
#  'ad71.jpg',
#  'ad72.jpg',
#  'ad73.jpg',
#  'ad74.jpg',
#  'ad75.jpg',
#  'ad76.jpg',
#  'ad77.jpg',
#  'ad78.jpg',
#  'ad79.jpg',
#  'ad8.jpg',
#  'ad80.jpg',
#  'ad81.jpg',
#  'ad82.jpg',
#  'ad83.jpg',
#  'ad84.jpg',
#  'ad85.jpg',
#  'ad86.jpg',
#  'ad87.jpg',
#  'ad88.jpg',
#  'ad89.jpg',
#  'ad9.jpg',
#  'ad90.jpg',
#  'ad91.jpg',
#  'ad92.jpg',
#  'ad93.jpg',
#  'ad94.jpg',
#  'ad95.jpg',
#  'ad96.jpg',
#  'ad97.jpg',
#  'ad98.jpg',
#  'ad99.jpg']

# %%
i = 1
for name in file_names:
    src = os.path.join(file_path, name)
    dst = 'ad' + str(i) + '.jpg'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-2-5ab22ba1d21a> in <module>
#       4     dst = 'ad' + str(i) + '.jpg'
#       5     dst = os.path.join(file_path, dst)
# ----> 6     os.rename(src, dst)
#       7     i += 1
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:\\Users\\kimkm\\광고\\ad\\ad10.jpg' -> 'C:\\Users\\kimkm\\광고\\ad\\ad2.jpg'

# %%
import os

file_path = 'C:\\Users\\kimkm\\광고\\non-ad'
file_names = os.listdir(file_path)
file_names
# Out:
# ['non-ad1.jpg',
#  'non-ad10.jpg',
#  'non-ad100.jpg',
#  'non-ad101.jpg',
#  'non-ad102.jpg',
#  'non-ad103.jpg',
#  'non-ad104.jpg',
#  'non-ad105.jpg',
#  'non-ad106.jpg',
#  'non-ad107.jpg',
#  'non-ad108.jpg',
#  'non-ad109.jpg',
#  'non-ad11.jpg',
#  'non-ad110.jpg',
#  'non-ad111.jpg',
#  'non-ad112.jpg',
#  'non-ad113.jpg',
#  'non-ad114.jpg',
#  'non-ad115.jpg',
#  'non-ad116.jpg',
#  'non-ad117.jpg',
#  'non-ad118.jpg',
#  'non-ad119.jpg',
#  'non-ad12.jpg',
#  'non-ad120.jpg',
#  'non-ad121.jpg',
#  'non-ad122.jpg',
#  'non-ad123.jpg',
#  'non-ad124.jpg',
#  'non-ad125.jpg',
#  'non-ad126.jpg',
#  'non-ad127.jpg',
#  'non-ad128.jpg',
#  'non-ad129.jpg',
#  'non-ad13.jpg',
#  'non-ad130.jpg',
#  'non-ad131.jpg',
#  'non-ad132.jpg',
#  'non-ad133.jpg',
#  'non-ad134.jpg',
#  'non-ad135.jpg',
#  'non-ad136.jpg',
#  'non-ad137.jpg',
#  'non-ad138.jpg',
#  'non-ad139.jpg',
#  'non-ad14.jpg',
#  'non-ad140.jpg',
#  'non-ad141.jpg',
#  'non-ad142.jpg',
#  'non-ad143.jpg',
#  'non-ad144.jpg',
#  'non-ad145.jpg',
#  'non-ad146.jpg',
#  'non-ad147.jpg',
#  'non-ad148.jpg',
#  'non-ad149.jpg',
#  'non-ad15.jpg',
#  'non-ad150.jpg',
#  'non-ad151.jpg',
#  'non-ad152.jpg',
#  'non-ad153.jpg',
#  'non-ad154.jpg',
#  'non-ad155.jpg',
#  'non-ad156.jpg',
#  'non-ad157.jpg',
#  'non-ad16.jpg',
#  'non-ad17.jpg',
#  'non-ad18.jpg',
#  'non-ad19.jpg',
#  'non-ad2.jpg',
#  'non-ad20.jpg',
#  'non-ad21.jpg',
#  'non-ad22.jpg',
#  'non-ad23.jpg',
#  'non-ad24.jpg',
#  'non-ad25.jpg',
#  'non-ad26.jpg',
#  'non-ad27.jpg',
#  'non-ad28.jpg',
#  'non-ad29.jpg',
#  'non-ad3.jpg',
#  'non-ad30.jpg',
#  'non-ad31.jpg',
#  'non-ad32.jpg',
#  'non-ad33.jpg',
#  'non-ad34.jpg',
#  'non-ad35.jpg',
#  'non-ad36.jpg',
#  'non-ad37.jpg',
#  'non-ad38.jpg',
#  'non-ad39.jpg',
#  'non-ad4.jpg',
#  'non-ad40.jpg',
#  'non-ad41.jpg',
#  'non-ad42.jpg',
#  'non-ad43.jpg',
#  'non-ad44.jpg',
#  'non-ad45.jpg',
#  'non-ad46.jpg',
#  'non-ad47.jpg',
#  'non-ad48.jpg',
#  'non-ad49.jpg',
#  'non-ad5.jpg',
#  'non-ad50.jpg',
#  'non-ad51.jpg',
#  'non-ad52.jpg',
#  'non-ad53.jpg',
#  'non-ad54.jpg',
#  'non-ad55.jpg',
#  'non-ad56.jpg',
#  'non-ad57.jpg',
#  'non-ad58.jpg',
#  'non-ad59.jpg',
#  'non-ad6.jpg',
#  'non-ad60.jpg',
#  'non-ad61.jpg',
#  'non-ad62.jpg',
#  'non-ad63.jpg',
#  'non-ad64.jpg',
#  'non-ad65.jpg',
#  'non-ad66.jpg',
#  'non-ad67.jpg',
#  'non-ad68.jpg',
#  'non-ad69.jpg',
#  'non-ad7.jpg',
#  'non-ad70.jpg',
#  'non-ad71.jpg',
#  'non-ad72.jpg',
#  'non-ad73.jpg',
#  'non-ad74.jpg',
#  'non-ad75.jpg',
#  'non-ad76.jpg',
#  'non-ad77.jpg',
#  'non-ad78.jpg',
#  'non-ad79.jpg',
#  'non-ad8.jpg',
#  'non-ad80.jpg',
#  'non-ad81.jpg',
#  'non-ad82.jpg',
#  'non-ad83.jpg',
#  'non-ad84.jpg',
#  'non-ad85.jpg',
#  'non-ad86.jpg',
#  'non-ad87.jpg',
#  'non-ad88.jpg',
#  'non-ad89.jpg',
#  'non-ad9.jpg',
#  'non-ad90.jpg',
#  'non-ad91.jpg',
#  'non-ad92.jpg',
#  'non-ad93.jpg',
#  'non-ad94.jpg',
#  'non-ad95.jpg',
#  'non-ad96.jpg',
#  'non-ad97.jpg',
#  'non-ad98.jpg',
#  'non-ad99.jpg']

# %%
i = 1
for name in file_names:
    src = os.path.join(file_path, name)
    dst = 'non-ad' + str(i) + '.jpg'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-6-37b28a8c7213> in <module>
#       4     dst = 'non-ad' + str(i) + '.jpg'
#       5     dst = os.path.join(file_path, dst)
# ----> 6     os.rename(src, dst)
#       7     i += 1
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:\\Users\\kimkm\\광고\\non-ad\\non-ad10.jpg' -> 'C:\\Users\\kimkm\\광고\\non-ad\\non-ad2.jpg'

# %%
본 코드 시작

from PIL import Image
import glob, sys, numpy as np
from sklearn.model_selection import train_test_split
from  keras.utils import np_utils

img_dir = 'C:\\Users\\kimkm\\광고'
categories = ['ad', 'non-ad']
np_classes = len(categories)

image_w = 64
image_h = 64


pixel = image_h * image_w * 3 # RGB 값

X = []
y = []

for idx, ad in enumerate(categories):
    img_dir_detail = img_dir + "\\" + ad
    files = glob.glob(img_dir_detail+"/*.jpg")


    for i, f in enumerate(files):
        try:
            img = Image.open(f)
            img = img.convert("RGB")
            img = img.resize((image_w, image_h))
            data = np.asarray(img)
            #Y는 0 아니면 1이니까 idx값으로 넣는다.
            X.append(data)
            y.append(idx)
            #if i % 300 == 0:
            print(ad, " : ", f)
        except:
            print(ad, str(i)+" 번째에서 에러 ")
X = np.array(X)
Y = np.array(y)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

xy = (X_train, X_test, Y_train, Y_test)
#np.save("C:\\Users\\kimkm\\Desktop\\캡스톤 디자인\\데이터 수집\\광고\\binary_image_data.npy", xy)
np.save("C:\\Users\\kimkm\\광고\\numpy_data\\binary_image_data.npy", xy)
# Out:
# ad  :  C:\Users\kimkm\광고\ad\ad1.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad10.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad100.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad101.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad102.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad103.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad104.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad105.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad106.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad107.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad108.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad109.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad11.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad110.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad111.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad112.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad113.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad114.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad115.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad116.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad117.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad118.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad119.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad12.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad120.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad121.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad122.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad123.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad124.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad125.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad126.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad127.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad128.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad129.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad13.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad130.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad131.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad132.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad133.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad134.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad135.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad14.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad15.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad16.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad17.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad18.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad19.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad2.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad20.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad21.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad22.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad23.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad24.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad25.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad26.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad27.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad28.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad29.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad3.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad30.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad31.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad32.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad33.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad34.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad35.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad36.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad37.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad38.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad39.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad4.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad40.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad41.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad42.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad43.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad44.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad45.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad46.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad47.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad48.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad49.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad5.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad50.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad51.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad52.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad53.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad54.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad55.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad56.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad57.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad58.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad59.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad6.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad60.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad61.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad62.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad63.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad64.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad65.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad66.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad67.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad68.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad69.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad7.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad70.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad71.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad72.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad73.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad74.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad75.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad76.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad77.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad78.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad79.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad8.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad80.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad81.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad82.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad83.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad84.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad85.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad86.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad87.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad88.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad89.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad9.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad90.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad91.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad92.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad93.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad94.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad95.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad96.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad97.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad98.jpg
# ad  :  C:\Users\kimkm\광고\ad\ad99.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad1.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad10.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad100.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad101.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad102.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad103.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad104.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad105.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad106.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad107.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad108.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad109.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad11.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad110.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad111.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad112.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad113.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad114.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad115.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad116.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad117.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad118.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad119.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad12.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad120.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad121.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad122.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad123.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad124.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad125.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad126.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad127.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad128.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad129.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad13.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad130.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad131.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad132.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad133.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad134.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad135.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad136.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad137.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad138.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad139.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad14.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad140.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad141.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad142.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad143.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad144.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad145.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad146.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad147.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad148.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad149.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad15.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad150.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad151.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad152.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad153.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad154.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad155.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad156.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad157.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad16.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad17.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad18.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad19.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad2.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad20.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad21.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad22.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad23.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad24.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad25.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad26.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad27.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad28.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad29.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad3.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad30.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad31.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad32.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad33.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad34.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad35.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad36.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad37.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad38.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad39.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad4.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad40.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad41.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad42.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad43.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad44.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad45.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad46.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad47.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad48.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad49.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad5.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad50.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad51.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad52.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad53.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad54.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad55.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad56.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad57.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad58.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad59.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad6.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad60.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad61.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad62.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad63.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad64.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad65.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad66.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad67.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad68.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad69.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad7.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad70.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad71.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad72.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad73.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad74.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad75.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad76.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad77.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad78.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad79.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad8.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad80.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad81.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad82.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad83.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad84.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad85.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad86.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad87.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad88.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad89.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad9.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad90.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad91.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad92.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad93.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad94.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad95.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad96.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad97.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad98.jpg
# non-ad  :  C:\Users\kimkm\광고\non-ad\non-ad99.jpg
# D:\anaconda3\lib\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

#X_train, X_test, y_train, y_test = np.load("C:\\Users\\kimkm\\Desktop\\캡스톤 디자인\\데이터 수집\\광고\\binary_image_data.npy", allow_pickle=True)
X_train, X_test, y_train, y_test = np.load("C:\\Users\\kimkm\\광고\\numpy_data\\binary_image_data.npy", allow_pickle=True)

print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (233, 64, 64, 3)
# 233
# [110 123]
# [25 34]

# %%
import os

image_w = 64
image_h = 64
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255


with K.tf_ops.device('/device:GPU:0'):
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu")) 
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) # optimizer와 loss 바꿔볼 것
    
    model_dir = 'C:\\Users\\kimkm\\광고\\model'
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    model_path = model_dir + "\\ad_non_ad_classify.model"
    
    checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    #model.save('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model.h5')
    early_stopping = EarlyStopping(monitor='val_loss', patience=7)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 328,225
# Trainable params: 328,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6923 - accuracy: 0.5677
# Epoch 00001: val_loss improved from inf to 0.69159, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 619ms/step - loss: 0.6931 - accuracy: 0.5606 - val_loss: 0.6916 - val_accuracy: 0.5143
# Epoch 2/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6936 - accuracy: 0.5208
# Epoch 00002: val_loss improved from 0.69159 to 0.68620, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 607ms/step - loss: 0.6951 - accuracy: 0.5152 - val_loss: 0.6862 - val_accuracy: 0.4857
# Epoch 3/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6972 - accuracy: 0.5104
# Epoch 00003: val_loss did not improve from 0.68620
# 4/4 [==============================] - 0s 78ms/step - loss: 0.6953 - accuracy: 0.5202 - val_loss: 0.6870 - val_accuracy: 0.4857
# Epoch 4/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6962 - accuracy: 0.5312
# Epoch 00004: val_loss did not improve from 0.68620
# 4/4 [==============================] - 0s 81ms/step - loss: 0.6946 - accuracy: 0.5303 - val_loss: 0.6875 - val_accuracy: 0.6571
# Epoch 5/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6973 - accuracy: 0.5417
# Epoch 00005: val_loss did not improve from 0.68620
# 4/4 [==============================] - 0s 78ms/step - loss: 0.6962 - accuracy: 0.5455 - val_loss: 0.6892 - val_accuracy: 0.5429
# Epoch 6/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6889 - accuracy: 0.5521
# Epoch 00006: val_loss improved from 0.68620 to 0.68567, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 578ms/step - loss: 0.6902 - accuracy: 0.5505 - val_loss: 0.6857 - val_accuracy: 0.6286
# Epoch 7/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6850 - accuracy: 0.5260
# Epoch 00007: val_loss improved from 0.68567 to 0.68383, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 618ms/step - loss: 0.6857 - accuracy: 0.5253 - val_loss: 0.6838 - val_accuracy: 0.6857
# Epoch 8/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6813 - accuracy: 0.5417
# Epoch 00008: val_loss did not improve from 0.68383
# 4/4 [==============================] - 0s 79ms/step - loss: 0.6811 - accuracy: 0.5455 - val_loss: 0.6893 - val_accuracy: 0.5429
# Epoch 9/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6672 - accuracy: 0.5781
# Epoch 00009: val_loss did not improve from 0.68383
# 4/4 [==============================] - 0s 82ms/step - loss: 0.6700 - accuracy: 0.5707 - val_loss: 0.6908 - val_accuracy: 0.5429
# Epoch 10/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6665 - accuracy: 0.5990
# Epoch 00010: val_loss improved from 0.68383 to 0.68024, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 581ms/step - loss: 0.6648 - accuracy: 0.6061 - val_loss: 0.6802 - val_accuracy: 0.6286
# Epoch 11/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6611 - accuracy: 0.6406
# Epoch 00011: val_loss improved from 0.68024 to 0.66954, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 562ms/step - loss: 0.6588 - accuracy: 0.6465 - val_loss: 0.6695 - val_accuracy: 0.5429
# Epoch 12/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6505 - accuracy: 0.6094
# Epoch 00012: val_loss improved from 0.66954 to 0.66138, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 3s 635ms/step - loss: 0.6564 - accuracy: 0.6010 - val_loss: 0.6614 - val_accuracy: 0.6857
# Epoch 13/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6947 - accuracy: 0.5208
# Epoch 00013: val_loss did not improve from 0.66138
# 4/4 [==============================] - 0s 82ms/step - loss: 0.6899 - accuracy: 0.5253 - val_loss: 0.7095 - val_accuracy: 0.5429
# Epoch 14/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6541 - accuracy: 0.5938
# Epoch 00014: val_loss did not improve from 0.66138
# 4/4 [==============================] - 0s 82ms/step - loss: 0.6524 - accuracy: 0.5960 - val_loss: 0.6857 - val_accuracy: 0.4857
# Epoch 15/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6450 - accuracy: 0.6198
# Epoch 00015: val_loss did not improve from 0.66138
# 4/4 [==============================] - 0s 80ms/step - loss: 0.6478 - accuracy: 0.6162 - val_loss: 0.6692 - val_accuracy: 0.6286
# Epoch 16/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6306 - accuracy: 0.6615
# Epoch 00016: val_loss did not improve from 0.66138
# 4/4 [==============================] - 0s 89ms/step - loss: 0.6280 - accuracy: 0.6667 - val_loss: 0.7041 - val_accuracy: 0.5429
# Epoch 17/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6408 - accuracy: 0.6146
# Epoch 00017: val_loss improved from 0.66138 to 0.65653, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 575ms/step - loss: 0.6365 - accuracy: 0.6212 - val_loss: 0.6565 - val_accuracy: 0.5429
# Epoch 18/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6665 - accuracy: 0.6302
# Epoch 00018: val_loss improved from 0.65653 to 0.65174, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 3s 635ms/step - loss: 0.6661 - accuracy: 0.6313 - val_loss: 0.6517 - val_accuracy: 0.6286
# Epoch 19/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6161 - accuracy: 0.6562
# Epoch 00019: val_loss improved from 0.65174 to 0.63874, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 599ms/step - loss: 0.6132 - accuracy: 0.6616 - val_loss: 0.6387 - val_accuracy: 0.7143
# Epoch 20/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5915 - accuracy: 0.6667
# Epoch 00020: val_loss improved from 0.63874 to 0.63406, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 3s 645ms/step - loss: 0.5855 - accuracy: 0.6768 - val_loss: 0.6341 - val_accuracy: 0.5429
# Epoch 21/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5692 - accuracy: 0.6510
# Epoch 00021: val_loss improved from 0.63406 to 0.61383, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 568ms/step - loss: 0.5674 - accuracy: 0.6515 - val_loss: 0.6138 - val_accuracy: 0.6571
# Epoch 22/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5123 - accuracy: 0.7448
# Epoch 00022: val_loss did not improve from 0.61383
# 4/4 [==============================] - 0s 80ms/step - loss: 0.5090 - accuracy: 0.7475 - val_loss: 0.6141 - val_accuracy: 0.6000
# Epoch 23/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5127 - accuracy: 0.7448
# Epoch 00023: val_loss improved from 0.61383 to 0.52613, saving model to C:\Users\kimkm\광고\model\ad_non_ad_classify.model
# INFO:tensorflow:Assets written to: C:\Users\kimkm\광고\model\ad_non_ad_classify.model\assets
# 4/4 [==============================] - 2s 582ms/step - loss: 0.5150 - accuracy: 0.7424 - val_loss: 0.5261 - val_accuracy: 0.7714
# Epoch 24/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.4765 - accuracy: 0.7448
# Epoch 00024: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 81ms/step - loss: 0.4695 - accuracy: 0.7525 - val_loss: 0.5298 - val_accuracy: 0.8000
# Epoch 25/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.4732 - accuracy: 0.7552
# Epoch 00025: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 81ms/step - loss: 0.4729 - accuracy: 0.7576 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 26/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5395 - accuracy: 0.6927
# Epoch 00026: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 78ms/step - loss: 0.5454 - accuracy: 0.6869 - val_loss: 0.7557 - val_accuracy: 0.5143
# Epoch 27/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8149 - accuracy: 0.6250
# Epoch 00027: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 80ms/step - loss: 0.8154 - accuracy: 0.6212 - val_loss: 0.6221 - val_accuracy: 0.6857
# Epoch 28/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5328 - accuracy: 0.7500
# Epoch 00028: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 81ms/step - loss: 0.5373 - accuracy: 0.7424 - val_loss: 0.7073 - val_accuracy: 0.5429
# Epoch 29/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.6222 - accuracy: 0.6094
# Epoch 00029: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 86ms/step - loss: 0.6162 - accuracy: 0.6162 - val_loss: 0.6599 - val_accuracy: 0.5429
# Epoch 30/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.5900 - accuracy: 0.6510
# Epoch 00030: val_loss did not improve from 0.52613
# 4/4 [==============================] - 0s 79ms/step - loss: 0.5911 - accuracy: 0.6515 - val_loss: 0.5883 - val_accuracy: 0.6571

# %%
print("정확도 : %.2f " %(model.evaluate(X_test, y_test)[1]))
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6145 - accuracy: 0.6949
# 정확도 : 0.69

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.show()

# %%
from PIL import Image
#import Image
import os, glob, numpy as np
from tensorflow.keras.models import load_model

import tensorflow as tf

seed = 5
tf.random.set_seed(seed)
np.random.seed(seed)

caltech_dir = 'C:\\Users\\kimkm\\광고\\test'


image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*.jpg")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)

    filenames.append(f)
    X.append(data)
    
X = np.array(X)
X = X.astype(float) / 255

model = load_model('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model')
#model = load_model('C:\\Users\\kimkm\\광고\\model\\ad_non_ad_classify.model.h5')


prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)}) # 소수점 3자리까지
cnt = 0
for i in prediction:
    if i >= 0.5: print("해당 " + filenames[cnt].split("\\")[4] + filenames[cnt].split("\\")[5] + "  이미지는 광고 로 추정됩니다.")
    else : print("해당 " + filenames[cnt].split("\\")[4] + filenames[cnt].split("\\")[5] + "  이미지는 비광고 로 추정됩니다.")
    cnt += 1
# Out:
# ['C:\\Users\\kimkm\\광고\\test\\1.jpg', 'C:\\Users\\kimkm\\광고\\test\\2.jpg', 'C:\\Users\\kimkm\\광고\\test\\3.jpg', 'C:\\Users\\kimkm\\광고\\test\\4.jpg', 'C:\\Users\\kimkm\\광고\\test\\5.jpg', 'C:\\Users\\kimkm\\광고\\test\\6.jpg', 'C:\\Users\\kimkm\\광고\\test\\7.jpg', 'C:\\Users\\kimkm\\광고\\test\\8.jpg', 'C:\\Users\\kimkm\\광고\\test\\9.jpg']
# 해당 test1.jpg  이미지는 광고 로 추정됩니다.
# 해당 test2.jpg  이미지는 광고 로 추정됩니다.
# 해당 test3.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test4.jpg  이미지는 광고 로 추정됩니다.
# 해당 test5.jpg  이미지는 광고 로 추정됩니다.
# 해당 test6.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test7.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test8.jpg  이미지는 비광고 로 추정됩니다.
# 해당 test9.jpg  이미지는 비광고 로 추정됩니다.
