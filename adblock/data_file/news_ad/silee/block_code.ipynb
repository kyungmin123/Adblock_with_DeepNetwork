# %%
# 한국경제
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

os.getcwd()
os.chdir("C:\\Users\\USER\\Pictures\\sample")
os.getcwd()

for t in range(3,51,1):
    im=Image.open(str(t)+'.PNG')
    px=im.load()
    
    for i in range(1920):
        for j in range(1030):
            px[i,j]=(255,255,255)
        
    for i in range(543,1355):
        for j in range(233,345):
            px[i,j]=(0,0,0)

    for i in range(309,443):
        for j in range(850,1030):
            px[i,j]=(0,0,0)

    for i in range(1170,1420):
        for j in range(710,1030):
            px[i,j]=(0,0,0)

    for i in range(473,607):
        for j in range(992,1030):
            px[i,j]=(0,0,0)

    # im.show()
    im.save(str(t+300)+'.PNG')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c83a5f579479> in <module>()
#       5
#       6 os.getcwd()
# ----> 7 os.chdir("C:\\Users\\USER\\Pictures\\sample")
#       8 os.getcwd()
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\USER\\Pictures\\sample'
